# %%
from openai import OpenAI
import json

# Initialize OpenAI client that points to the local LM Studio server
client = OpenAI(
    base_url="http://localhost:1234/v1",
    api_key="lm-studio"
)

# Define the conversation with the AI
messages = [
    {"role": "system", "content": "You are a helpful AI assistant."},
    {"role": "user", "content": "Create 1-3 fictional characters"}
]

# Define the expected response structure
character_schema = {
    "type": "json_schema",
    "json_schema": {
        "name": "characters",
        "schema": {
            "type": "object",
            "properties": {
                "characters": {
                    "type": "array",
                    "items": {
                        "type": "object",
                        "properties": {
                            "name": {"type": "string"},
                            "occupation": {"type": "string"},
                            "personality": {"type": "string"},
                            "background": {"type": "string"}
                        },
                        "required": ["name", "occupation", "personality", "background"]
                    },
                    "minItems": 1,
                }
            },
            "required": ["characters"]
        },
    }
}

# Get response from AI
response = client.chat.completions.create(
    model="your-model",
    messages=messages,
    response_format=character_schema,
)

# Parse and display the results
results = json.loads(response.choices[0].message.content)
print(json.dumps(results, indent=2))
# Out:
# {
#   "characters": [
#     {
#       "name": "Lira Moonshadow",
#       "occupation": "Arcane Cartographer",
#       "personality": "Curious, introspective, and fiercely independent. Lira speaks rarely but when she does, her words hold weight. She is fascinated by forgotten places and the magic that lingers in them.",
#       "background": "Lira was born under a rare celestial alignment known as the Silent Convergence, which is said to grant its recipients an innate bond with ancient magic. Raised by a reclusive order of scholars, she learned to map the physical and mystical worlds alike. Her maps are legendary\u2014accurate in both location and enchantment."
#     },
#     {
#       "name": "Zephyr Dusk",
#       "occupation": "Skybound Gambler and Aviator",
#       "personality": "Charismatic, impulsive, and roguish with a heart of gold. Zephyr thrives on risk, whether it\u2019s in high-stakes games or dangerous aerial stunts.",
#       "background": "Once a member of the elite Skyward Guild, Zephyr was cast out for cheating in a tournament\u2014though he claims the game itself had cheated against him. Now, he travels between floating cities and skyports, making bets others wouldn't dare dream of. His airship, *The Duskhawk*, is as much a part of him as his shadow."
#     },
#     {
#       "name": "Professor Thaddeus Grimblewick",
#       "occupation": "Clockwork Alchemist and Mad Inventor",
#       "personality": "Obsessive, brilliant, and socially awkward. Thaddeus is endlessly inventive but has a tendency to forget the world around him, often speaking in riddles or absentmindedly combining unrelated elements.",
#       "background": "Born into a prestigious family of alchemists, Thaddeus abandoned his noble title to chase the dream of merging living magic with mechanical constructs. Though many mock him as a madman, his creations\u2014like the self-replicating inkwells and emotion-measuring teapots\u2014are quietly revolutionizing both science and art."
#     }
#   ]
# }
